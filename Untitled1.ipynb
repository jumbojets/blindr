# %%
from sdk.blinder_client import MyAPIClient
from sdk.blinder_config import BlindrConfig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sdk.blinder_client import MyAPIClient
#       2 from sdk.blinder_config import BlindrConfig
#
# ModuleNotFoundError: No module named 'sdk.blinder_client'
